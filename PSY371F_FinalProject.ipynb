# %%
import pandas as pd

df = pd.read_csv('data/Male baboons GC and T3 Anonymized.csv')
df
# Out:
#       Male_ID Group_ID Collection_date  Hydroyear  T3_conc  GC_conc  \
# 0         110        F       11/4/2004       2005    66.73    29.06
# 1          19        F       11/4/2004       2005   104.48    38.89
# 2         172        D       11/5/2004       2005   133.03    64.19
# 3         116        D       11/5/2004       2005    77.25    27.78
# 4          63        D       11/5/2004       2005   109.12    74.61
# ...       ...      ...             ...        ...      ...      ...
# 4692      113        H      12/31/2015       2016   196.14   110.89
# 4693      180        G      12/31/2015       2016   135.99   184.61
# 4694      102        H      12/31/2015       2016   147.48    98.59
# 4695      125        L      12/31/2016       2017    73.78    96.69
# 4696      125        L      12/31/2015       2016   118.39    82.31
#
#           Season  Rainfall   Tav  Group_size  ... Unnamed: 21  Unnamed: 22  \
# ...
